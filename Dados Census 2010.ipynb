# %%
import geopandas as gpd
import pandas as pd

# %%
DEFAULT_CRS = "EPSG:4326"

# %%
censu_gpd = gpd.read_file("data/SC2010_CEM_RMSAO_V4")

# %%
censu_gpd.head()
# Out:
#         ID   AREA  DATA       SC_2010       SC_2010_CH        AP_2010  \
# 0  2895191  14.88   602  3.546801e+14  354680105000064  3546801003001
# 1  2905077  13.30  1082  3.530607e+14  353060705000181  3530607005007
# 2  2894895   9.65  1081  3.530607e+14  353060705000180  3530607005007
# 3  2905096   6.10  1083  3.530607e+14  353060705000182  3530607005007
# 4  2905155   1.23   603  3.530607e+14  353060705000164  3530607005007
#
#       AP_2010_CH       SC_2000       SC_2000_CH  COD_GR  ...   BA_007  BA_009  \
# 0  3546801003001  3.546801e+14  354680105000064       3  ...  1195.91  578.19
# 1  3530607005007  3.530607e+14  353060705000160       3  ...  1042.77  574.84
# 2  3530607005007  3.530607e+14  353060705000159       3  ...   865.09  413.37
# 3  3530607005007  3.530607e+14  353060705000161       3  ...  1754.07  893.20
# 4  3530607005007  3.530607e+14  353060705000149       3  ...   876.96  429.70
#
#     BA_011   AREA_KM2 DENS_KM2  SITUA1_201 SITUA_2_20  TIPO_2016 TIPO_2_201  \
# 0   991.61  14.881440       26         8.0      RURAL          0          N
# 1   907.13  13.298441       58         8.0      RURAL          0          N
# 2   704.50   9.645352       41         8.0      RURAL          0          N
# 3  1335.42   6.101509       58         8.0      RURAL          0          N
# 4   763.29   1.225181      515         3.0     URBANO          0          N
#
#                                             geometry
# 0  POLYGON ((-46.17788 -23.35886, -46.17866 -23.3...
# 1  POLYGON ((-46.21148 -23.37766, -46.21124 -23.3...
# 2  POLYGON ((-46.21148 -23.37766, -46.21119 -23.3...
# 3  POLYGON ((-46.17788 -23.35886, -46.17665 -23.3...
# 4  POLYGON ((-46.15525 -23.36233, -46.15625 -23.3...
#
# [5 rows x 44 columns]

# %% [markdown]
# Read tables values

# %%
variables = pd.read_excel("data/SC2010_CEM_RMSAO_V4/SC2010_CEM_RMSAO.xlsx", usecols=["CODSETOR", "CODSETTX", "COD_RM", "NOM_RM", "D1_012", "D1_017", "D1_035", "D1_044"])

# %%
variables.head()
# Out:
#           CODSETOR         CODSETTX  COD_RM        NOM_RM  D1_012  D1_017  \
# 0  350390105000001  350390105000001      20  RM SAO PAULO   109.0   107.0
# 1  350390105000002  350390105000002      20  RM SAO PAULO   151.0   151.0
# 2  350390105000003  350390105000003      20  RM SAO PAULO   175.0   169.0
# 3  350390105000004  350390105000004      20  RM SAO PAULO   234.0   216.0
# 4  350390105000005  350390105000005      20  RM SAO PAULO   106.0    93.0
#
#    D1_035  D1_044
# 0   109.0   109.0
# 1   151.0   151.0
# 2   175.0   175.0
# 3   238.0   238.0
# 4   106.0   106.0

# %%
variables[variables['CODSETOR'] == 355030832000011]
# Out:
#               CODSETOR         CODSETTX  COD_RM        NOM_RM  D1_012  D1_017  \
# 17221  355030832000011  355030832000011      20  RM SAO PAULO    94.0    94.0
#
#        D1_035  D1_044
# 17221    94.0    94.0

# %%
variables.dtypes
# Out:
# CODSETOR      int64
# CODSETTX      int64
# COD_RM        int64
# NOM_RM       object
# D1_012      float64
# D1_017      float64
# D1_035      float64
# D1_044      float64
# dtype: object

# %%
censu_gpd = (censu_gpd
             .join(variables[['CODSETOR', 'D1_012', 'D1_017', 'D1_035', 'D1_044']].set_index("CODSETOR"),
                    how='left',
                    on='SC_2010'
                )
            )

# %% [markdown]
# Criar variáveis com as densidades das variavies de acesso

# %%
censu_gpd["area_poly"] = (
    censu_gpd
    .geometry
    .to_crs("EPSG:5641")
    .area) # Area may be invalid for a geographic CRS using degrees as units; use GeoSeries.to_crs() to project geometries to a planar CRS before using this function.

# %%
def calculate_var_density(gpd, var, area):
    return gpd[var]/gpd[area]

# %%
censu_gpd["D1_012_d"] = calculate_var_density(censu_gpd, 'D1_012', 'area_poly')
censu_gpd["D1_017_d"] = calculate_var_density(censu_gpd, 'D1_017', 'area_poly')
censu_gpd["D1_035_d"] = calculate_var_density(censu_gpd, 'D1_035', 'area_poly')
censu_gpd["D1_044_d"] = calculate_var_density(censu_gpd, 'D1_044', 'area_poly')

# %%
censu_gpd.head()
# Out:
#         ID   AREA  DATA       SC_2010       SC_2010_CH        AP_2010  \
# 0  2895191  14.88   602  3.546801e+14  354680105000064  3546801003001
# 1  2905077  13.30  1082  3.530607e+14  353060705000181  3530607005007
# 2  2894895   9.65  1081  3.530607e+14  353060705000180  3530607005007
# 3  2905096   6.10  1083  3.530607e+14  353060705000182  3530607005007
# 4  2905155   1.23   603  3.530607e+14  353060705000164  3530607005007
#
#       AP_2010_CH       SC_2000       SC_2000_CH  COD_GR  ...  \
# 0  3546801003001  3.546801e+14  354680105000064       3  ...
# 1  3530607005007  3.530607e+14  353060705000160       3  ...
# 2  3530607005007  3.530607e+14  353060705000159       3  ...
# 3  3530607005007  3.530607e+14  353060705000161       3  ...
# 4  3530607005007  3.530607e+14  353060705000149       3  ...
#
#                                             geometry  D1_012 D1_017  D1_035  \
# 0  POLYGON ((-46.17788 -23.35886, -46.17866 -23.3...     3.0    0.0    97.0
# 1  POLYGON ((-46.21148 -23.37766, -46.21124 -23.3...     6.0    2.0   146.0
# 2  POLYGON ((-46.21148 -23.37766, -46.21119 -23.3...     1.0    1.0    39.0
# 3  POLYGON ((-46.17788 -23.35886, -46.17665 -23.3...     0.0    4.0   101.0
# 4  POLYGON ((-46.15525 -23.36233, -46.15625 -23.3...     4.0    4.0   191.0
#
#   D1_044     area_poly      D1_012_d      D1_017_d  D1_035_d  D1_044_d
# 0  125.0  1.757641e+07  1.706834e-07  0.000000e+00  0.000006  0.000007
# 1  205.0  1.571155e+07  3.818847e-07  1.272949e-07  0.000009  0.000013
# 2   97.0  1.139932e+07  8.772451e-08  8.772451e-08  0.000003  0.000009
# 3  109.0  7.207873e+06  0.000000e+00  5.549487e-07  0.000014  0.000015
# 4  186.0  1.446876e+06  2.764577e-06  2.764577e-06  0.000132  0.000129
#
# [5 rows x 53 columns]

# %% [markdown]
# Colunas de interesse

# %%
censu_gpd = censu_gpd[['ID', 'SC_2010', 'geometry', 'D1_012_d', 'D1_017_d', 'D1_035_d', 'D1_044_d']]

# %% [markdown]
# # Lendo H3

# %%
hex_sp = gpd.read_file("data/shapeFiles/wgs84_hex_grid_sp_v2")

# %%
hex_sp.head()
# Out:
#       fid           id_hex abbrev_mun  name_muni  code_muni  \
# 0  2563.0  89a81009a8bffff        spo  Sao Paulo  3550308.0
# 1  2564.0  89a8108dca7ffff        spo  Sao Paulo  3550308.0
# 2  2565.0  89a81015a8bffff        spo  Sao Paulo  3550308.0
# 3  2566.0  89a810019d7ffff        spo  Sao Paulo  3550308.0
# 4  2567.0  89a8100d9d7ffff        spo  Sao Paulo  3550308.0
#
#                                             geometry
# 0  POLYGON ((-46.43596 -23.58661, -46.43800 -23.5...
# 1  POLYGON ((-46.77886 -23.89706, -46.78089 -23.8...
# 2  POLYGON ((-46.74000 -23.72290, -46.74204 -23.7...
# 3  POLYGON ((-46.62778 -23.65457, -46.62982 -23.6...
# 4  POLYGON ((-46.62335 -23.50435, -46.62539 -23.5...

# %% [markdown]
# # Intersect data

# %%
if censu_gpd.crs != DEFAULT_CRS:
    censu_gpd = censu_gpd.to_crs(DEFAULT_CRS)
if hex_sp.crs != DEFAULT_CRS:
    hex_sp = hex_sp.to_crs(DEFAULT_CRS)

# %%
censu_join_h3 =  censu_gpd.overlay(hex_sp[['fid', 'geometry']], how='intersection')

# %% [markdown]
# Gerar qnt de cada variável referente a área de recorte do censu nos hexagonos

# %%
censu_join_h3["area_poly"] = (
    censu_join_h3
    .geometry
    .to_crs("EPSG:5641")
    .area) # Area may be invalid for a geographic CRS using degrees as units; use GeoSeries.to_crs() to project geometries to a planar CRS before using this function.

censu_join_h3["D1_012_d"] = censu_join_h3["area_poly"] * censu_join_h3["D1_012_d"]
censu_join_h3["D1_017_d"] = censu_join_h3["area_poly"] * censu_join_h3["D1_017_d"]
censu_join_h3["D1_035_d"] = censu_join_h3["area_poly"] * censu_join_h3["D1_035_d"]
censu_join_h3["D1_044_d"] = censu_join_h3["area_poly"] * censu_join_h3["D1_044_d"]

# %%
censu_join_h3[censu_join_h3["SC_2010"] == 355030832000011]
# Out:
#          ID       SC_2010  D1_012_d  D1_017_d  D1_035_d  D1_044_d      fid  \
# 6   1928880  3.550308e+14  0.373261  0.373261  0.373261  0.373261   3794.0
# 7   1928880  3.550308e+14  6.250081  6.250081  6.250081  6.250081   6882.0
# 8   1928880  3.550308e+14  4.712445  4.712445  4.712445  4.712445   7107.0
# 9   1928880  3.550308e+14  6.250185  6.250185  6.250185  6.250185   7318.0
# 10  1928880  3.550308e+14  6.250136  6.250136  6.250136  6.250136   7532.0
# 11  1928880  3.550308e+14  1.368813  1.368813  1.368813  1.368813   7745.0
# 12  1928880  3.550308e+14  5.220015  5.220015  5.220015  5.220015   7962.0
# 13  1928880  3.550308e+14  2.126296  2.126296  2.126296  2.126296   8182.0
# 14  1928880  3.550308e+14  0.495271  0.495271  0.495271  0.495271   8368.0
# 15  1928880  3.550308e+14  3.016311  3.016311  3.016311  3.016311   8816.0
# 16  1928880  3.550308e+14  3.143822  3.143822  3.143822  3.143822   9260.0
# 17  1928880  3.550308e+14  2.359939  2.359939  2.359939  2.359939  13054.0
# 18  1928880  3.550308e+14  6.250288  6.250288  6.250288  6.250288  13276.0
# 19  1928880  3.550308e+14  0.790634  0.790634  0.790634  0.790634  13698.0
# 20  1928880  3.550308e+14  0.187429  0.187429  0.187429  0.187429  13789.0
# 21  1928880  3.550308e+14  2.815724  2.815724  2.815724  2.815724  14137.0
# 22  1928880  3.550308e+14  1.594538  1.594538  1.594538  1.594538  14677.0
# 23  1928880  3.550308e+14  6.250295  6.250295  6.250295  6.250295  14796.0
# 24  1928880  3.550308e+14  6.250246  6.250246  6.250246  6.250246  15026.0
# 25  1928880  3.550308e+14  1.417550  1.417550  1.417550  1.417550  15248.0
# 26  1928880  3.550308e+14  1.483682  1.483682  1.483682  1.483682  15472.0
# 27  1928880  3.550308e+14  3.496315  3.496315  3.496315  3.496315  15542.0
# 28  1928880  3.550308e+14  6.250240  6.250240  6.250240  6.250240  15697.0
# 29  1928880  3.550308e+14  6.250191  6.250191  6.250191  6.250191  15925.0
# 30  1928880  3.550308e+14  5.299714  5.299714  5.299714  5.299714  16152.0
# 31  1928880  3.550308e+14  4.096582  4.096582  4.096582  4.096582  16438.0
#
#                                              geometry      area_poly
# 6   POLYGON ((-46.66439 -23.59517, -46.66457 -23.5...    7523.883764
# 7   POLYGON ((-46.66168 -23.59317, -46.66265 -23.5...  125984.066365
# 8   POLYGON ((-46.66436 -23.58964, -46.66421 -23.5...   94989.636385
# 9   POLYGON ((-46.65858 -23.59178, -46.65955 -23.5...  125986.151216
# 10  POLYGON ((-46.66159 -23.59010, -46.66256 -23.5...  125985.173636
# 11  POLYGON ((-46.66271 -23.59461, -46.66168 -23.5...   27591.418897
# 12  POLYGON ((-46.66283 -23.59465, -46.66469 -23.5...  105220.822011
# 13  POLYGON ((-46.65836 -23.59317, -46.65947 -23.5...   42860.155228
# 14  POLYGON ((-46.65878 -23.57685, -46.65820 -23.5...    9983.270313
# 15  POLYGON ((-46.66331 -23.58135, -46.66351 -23.5...   60800.359472
# 16  POLYGON ((-46.66157 -23.57920, -46.66148 -23.5...   63370.611840
# 17  POLYGON ((-46.65101 -23.59080, -46.65152 -23.5...   47569.733716
# 18  POLYGON ((-46.65548 -23.59039, -46.65645 -23.5...  125988.234999
# 19  POLYGON ((-46.65186 -23.58902, -46.65237 -23.5...   15936.967266
# 20  POLYGON ((-46.65777 -23.57594, -46.65730 -23.5...    3778.047490
# 21  POLYGON ((-46.65334 -23.59145, -46.65394 -23.5...   56757.079291
# 22  POLYGON ((-46.65660 -23.57708, -46.65731 -23.5...   32141.409844
# 23  POLYGON ((-46.65840 -23.58565, -46.65937 -23.5...  125988.365162
# 24  POLYGON ((-46.66141 -23.58397, -46.66238 -23.5...  125987.387278
# 25  POLYGON ((-46.65568 -23.58273, -46.65468 -23.5...   28573.815129
# 26  POLYGON ((-46.65785 -23.58157, -46.65620 -23.5...   29906.865568
# 27  POLYGON ((-46.66343 -23.58234, -46.66238 -23.5...   70475.875158
# 28  POLYGON ((-46.65849 -23.58871, -46.65946 -23.5...  125987.258339
# 29  POLYGON ((-46.66150 -23.58704, -46.66247 -23.5...  125986.280607
# 30  POLYGON ((-46.65342 -23.58447, -46.65331 -23.5...  106827.343036
# 31  POLYGON ((-46.66410 -23.58760, -46.66382 -23.5...   82575.585313

# %%
censu_join_h3.head()
# Out:
#         ID       SC_2010   D1_012_d   D1_017_d   D1_035_d   D1_044_d      fid  \
# 0  1037688  3.550308e+14  13.284932  13.284932  13.284932  13.284932   8816.0
# 1  1037688  3.550308e+14   4.058893   4.058893   4.058893   4.058893  15093.0
# 2  1037688  3.550308e+14  24.433651  24.433651  24.433651  24.433651  15319.0
# 3  1037688  3.550308e+14  19.642940  19.642940  19.642940  19.642940  15542.0
# 4  1037688  3.550308e+14  32.307510  32.307510  32.307510  32.307510  15768.0
#
#                                             geometry     area_poly
# 0  POLYGON ((-46.66367 -23.58103, -46.66351 -23.5...  27359.189882
# 1  MULTIPOLYGON (((-46.66532 -23.58491, -46.66610...   8358.944750
# 2  POLYGON ((-46.66813 -23.58417, -46.66838 -23.5...  50319.030414
# 3  POLYGON ((-46.66363 -23.58391, -46.66493 -23.5...  40452.968782
# 4  POLYGON ((-46.66650 -23.58317, -46.66735 -23.5...  66534.574566

# %%
agg_variables_by_hex = censu_join_h3.groupby(['fid']).agg({
    "D1_012_d": ['sum'],
    "D1_017_d": ['sum'],
    "D1_035_d": ['sum'],
    "D1_044_d": ['sum'],

}).reset_index()

# %%
agg_variables_by_hex.columns = ['_'.join(col).strip() for col in agg_variables_by_hex.columns.values if col != 'fid']

# %%
agg_variables_by_hex.head()
# Out:
#      fid_  D1_012_d_sum  D1_017_d_sum  D1_035_d_sum  D1_044_d_sum
# 0  2563.0    152.372083    117.495154    172.151288    175.365031
# 1  2564.0      0.014834      0.000000      0.267007      0.178005
# 2  2565.0     10.161207      8.451977     10.924975     10.993266
# 3  2566.0      0.260353      0.023668      0.260353      0.260353
# 4  2567.0    216.861985    216.773123    216.861985    216.861985

# %%
agg_variables_by_hex["D1_012_d_sum"] = agg_variables_by_hex["D1_012_d_sum"].fillna(0)
agg_variables_by_hex["D1_017_d_sum"] = agg_variables_by_hex["D1_017_d_sum"].fillna(0)
agg_variables_by_hex["D1_035_d_sum"] = agg_variables_by_hex["D1_035_d_sum"].fillna(0)
agg_variables_by_hex["D1_044_d_sum"] = agg_variables_by_hex["D1_044_d_sum"].fillna(0)

# %%
agg_variables_by_hex[agg_variables_by_hex["fid_"] == 3794.0]
# Out:
#         fid_  D1_012_d_sum  D1_017_d_sum  D1_035_d_sum  D1_044_d_sum
# 1229  3794.0    298.824212    298.824212    298.824212    298.824212

# %%
agg_variables_by_hex.isna().sum()
# Out:
# fid_            0
# D1_012_d_sum    0
# D1_017_d_sum    0
# D1_035_d_sum    0
# D1_044_d_sum    0
# dtype: int64

# %%
hex_censu_final = hex_sp.join(agg_variables_by_hex.set_index('fid_'), how='left', on='fid')

# %%
hex_censu_final.head()
# Out:
#       fid           id_hex abbrev_mun  name_muni  code_muni  \
# 0  2563.0  89a81009a8bffff        spo  Sao Paulo  3550308.0
# 1  2564.0  89a8108dca7ffff        spo  Sao Paulo  3550308.0
# 2  2565.0  89a81015a8bffff        spo  Sao Paulo  3550308.0
# 3  2566.0  89a810019d7ffff        spo  Sao Paulo  3550308.0
# 4  2567.0  89a8100d9d7ffff        spo  Sao Paulo  3550308.0
#
#                                             geometry  D1_012_d_sum  \
# 0  POLYGON ((-46.43596 -23.58661, -46.43800 -23.5...    152.372083
# 1  POLYGON ((-46.77886 -23.89706, -46.78089 -23.8...      0.014834
# 2  POLYGON ((-46.74000 -23.72290, -46.74204 -23.7...     10.161207
# 3  POLYGON ((-46.62778 -23.65457, -46.62982 -23.6...      0.260353
# 4  POLYGON ((-46.62335 -23.50435, -46.62539 -23.5...    216.861985
#
#    D1_017_d_sum  D1_035_d_sum  D1_044_d_sum
# 0    117.495154    172.151288    175.365031
# 1      0.000000      0.267007      0.178005
# 2      8.451977     10.924975     10.993266
# 3      0.023668      0.260353      0.260353
# 4    216.773123    216.861985    216.861985

# %%
hex_censu_final["hex_fid"] = hex_censu_final["fid"].astype(int) #geopandas as a bug with fid https://github.com/geopandas/geopandas/issues/1035
hex_censu_final.drop("fid", inplace=True, axis=1)
hex_censu_final["D1_012_d_sum"] = hex_censu_final["D1_012_d_sum"].round()
hex_censu_final["D1_017_d_sum"] = hex_censu_final["D1_017_d_sum"].round()
hex_censu_final["D1_035_d_sum"] = hex_censu_final["D1_035_d_sum"].round()
hex_censu_final["D1_044_d_sum"] = hex_censu_final["D1_044_d_sum"].round()

# %%
hex_censu_final.to_file("data/WGS84_hex_census_2010.gpkg", driver="GPKG")
